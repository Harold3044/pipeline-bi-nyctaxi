# %%
# %sql
-- Crear el catálogo del proyecto
CREATE CATALOG IF NOT EXISTS proyecto_bi;

-- Crear los esquemas por capa
CREATE SCHEMA IF NOT EXISTS proyecto_bi.bronze;
CREATE SCHEMA IF NOT EXISTS proyecto_bi.silver;
CREATE SCHEMA IF NOT EXISTS proyecto_bi.gold;

# %%
# %sql
DROP SCHEMA IF EXISTS proyecto_bi.bronze CASCADE;

# %%
SHOW SCHEMAS IN proyecto_bi;
